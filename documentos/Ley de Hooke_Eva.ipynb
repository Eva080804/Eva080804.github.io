# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def Show_different_sigmas(x):
    # We see the function for different sigma values:
    sigma = [0.5, 1, 2]
    for i in sigma:
        noise = np.random.normal (0, i, N)
        F = -k * x + noise
        plt.scatter(x, F, label='Data with noise', color='blue', alpha=0.7)
        plt.xlabel('Desplacement (x)')
        plt.ylabel('Force (F)')
        plt.title ("Noisy data generated using Hooke ’s law")
        plt.legend ()
        plt.show ()
    return

# Parameters we're going to use:
k = 5 #Spring constant
sigma = 1
N = 100 #Number of iterations

#Generate data
x = np.linspace(0, 10, N)
Show_different_sigmas(x)

noise = np.random.normal (0, sigma, N) #We build a gaussian noise
F = -k * x + noise #We describe the hooke law in out parameters

#Split the data
x_train, x_test, F_train, F_test = train_test_split(x, F, test_size= 0.1, random_state=42)

#Lineal model
poly = PolynomialFeatures(degree = 1)
x_train_poly = poly.fit_transform(x_train.reshape(-1, 1))
x_test_poly = poly.transform(x_test.reshape(-1, 1))

model = LinearRegression()
model.fit(x_train_poly, F_train)

#Predictions
F_train_pred = model.predict(x_train_poly)
F_test_pred = model.predict(x_test_poly)

# Calculate errors
E_in = mean_squared_error(F_train, F_train_pred)
E_out = mean_squared_error(F_test, F_test_pred)

print(f'In-sample error (E_in): {E_in}')
print(f'Out-of-sample error (E_out): {E_out}')

# Plot the errors
plt.scatter(x_train, F_train, label='Training data', color='green', alpha=0.7)
plt.scatter(x_test, F_test, label='Test data', color='orange', alpha=0.7)
plt.plot(x, model.predict(poly.transform(x.reshape(-1, 1))), label='Fitted model', color='red')
plt.xlabel('Displacement (x)')
plt.ylabel('Force (F)')
plt.title('Model fit visualization')
plt.legend()
plt.show()
# Out:
# In-sample error (E_in): 0.9985734367677708
# Out-of-sample error (E_out): 0.7928478300209576

# %% [markdown]
# We can see that if we change sigma we're going to get the same points but desplaced from the original line.

# %% [markdown]
# Calculate the problem with the training and test x being different.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Parameters we're going to use:
k = 5 #Spring constant
sigma = 1
N = 100 #Number of iterations

#Generate data
x = np.linspace(0, 8, N)
x2 = np.linspace(8, 10, N)
noise = np.random.normal (0, sigma, N)
F = -k * x + noise
F2 = -k * x2 + noise
plt.scatter(x, F, label = 'Data with noise', color= 'blue', alpha= 0.7)
plt.scatter(x2, F2, label = 'Data with noise', color= 'red', alpha= 0.7)
plt.xlabel('Desplacement (x)')
plt.ylabel('Force (F)')
plt.title ("Noisy data generated using Hooke’s law")
plt.legend ()
plt.show ()

# Assign the train and the test to each x and x2 and do the same as the force.
x_train = x
x_test = x2
F_train = F
F_test = F2

poly = PolynomialFeatures(degree=1)
x_train_poly = poly.fit_transform(x_train.reshape(-1, 1))
x_test_poly = poly.transform(x_test.reshape(-1, 1))

model = LinearRegression()
model.fit(x_train_poly, F_train)

#Predictions
F_train_pred = model.predict(x_train_poly)
F_test_pred = model.predict(x_test_poly)

# Calculate errors
E_in = mean_squared_error(F_train, F_train_pred)
E_out = mean_squared_error(F_test, F_test_pred)

print(f'In-sample error (E_in): {E_in}')
print(f'Out-of-sample error (E_out): {E_out}')


# Plot the errors
plt.scatter(x_train, F_train, label='Training data', color='green', alpha=0.7)
plt.scatter(x_test, F_test, label='Test data', color='orange', alpha=0.7)
plt.plot(x, model.predict(poly.transform(x.reshape(-1, 1))), label='Fitted model', color='red')
plt.xlabel('Displacement (x)')
plt.ylabel('Force (F)')
plt.title('Model fit visualization')
plt.legend()
plt.show()
# Out:
# In-sample error (E_in): 0.836483497576577
# Out-of-sample error (E_out): 0.857973522524909

# %% [markdown]
# Calculate the problem for diferent degrees.
#
# We can switch the degree into 2, 3, 4... and we can see how change against the degree 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def Show_different_sigmas(x):
    sigma = [0.5, 1, 2]
    for i in sigma:
        noise = np.random.normal (0, i, N)
        F = -k * x + noise
        plt.scatter(x, F, label = 'Data with noise', color= 'blue', alpha= 0.7)
        plt.xlabel('Desplacement (x)')
        plt.ylabel('Force (F)')
        plt.title ("Noisy data generated using Hooke ’s law")
        plt.legend ()
        plt.show ()
    return
# Parameters we're going to use:
k = 5 #Spring constant
sigma = 1
N = 100 #Number of iterations

#Generate data
x = np.linspace(0, 10, N)
Show_different_sigmas(x)

noise = np.random.normal (0, sigma, N) #We build a gaussian noise
F = -k * x + noise #We describe the hooke law in out parameters

#Split the data
x_train, x_test, F_train, F_test = train_test_split(x, F, test_size= 0.1, random_state=42)

#Lineal model
poly = PolynomialFeatures(degree = 2)
x_train_poly = poly.fit_transform(x_train.reshape(-1, 1))
x_test_poly = poly.transform(x_test.reshape(-1, 1))

model = LinearRegression()
model.fit(x_train_poly, F_train)

#Predictions
F_train_pred = model.predict(x_train_poly)
F_test_pred = model.predict(x_test_poly)

# Calculate errors
E_in = mean_squared_error(F_train, F_train_pred)
E_out = mean_squared_error(F_test, F_test_pred)

print(f'In-sample error (E_in): {E_in}')
print(f'Out-of-sample error (E_out): {E_out}')


plt.scatter(x_train, F_train, label='Training data', color='green', alpha=0.7)
plt.scatter(x_test, F_test, label='Test data', color='orange', alpha=0.7)
plt.plot(x, model.predict(poly.transform(x.reshape(-1, 1))), label='Fitted model', color='red')
plt.xlabel('Displacement (x)')
plt.ylabel('Force (F)')
plt.title('Model fit visualization')
plt.legend()
plt.show()
# Out:
# In-sample error (E_in): 0.9011758414680541
# Out-of-sample error (E_out): 0.7483253709466842
